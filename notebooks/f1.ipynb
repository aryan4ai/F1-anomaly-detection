# %%
pip install fastf1 pandas numpy matplotlib scikit-learn
# Out:
# Collecting fastf1
#   Downloading fastf1-3.8.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pandas in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (2.3.4)
# Requirement already satisfied: matplotlib in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (3.10.7)
# Requirement already satisfied: scikit-learn in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (1.8.0)
# Collecting cryptography (from fastf1)
#   Downloading cryptography-50.0.1-cp311-abi3-win_amd64.whl.metadata (4.3 kB)
# Requirement already satisfied: platformdirs in C:\Users\aryan\AppData\Roaming\Python\Python313\site-packages (from fastf1) (4.9.6)
# Requirement already satisfied: pydantic in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastf1) (2.12.5)
# Collecting pyjwt (from fastf1)
#   Downloading pyjwt-2.13.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: python-dateutil in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastf1) (2.9.0.post0)
# Collecting rapidfuzz (from fastf1)
#   Downloading rapidfuzz-3.14.6-cp313-cp313-win_amd64.whl.metadata (12 kB)
# Collecting requests-cache>=1.0.0 (from fastf1)
#   Downloading requests_cache-1.3.3-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: requests>=2.30.0 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastf1) (2.32.5)
# Requirement already satisfied: scipy<2.0.0,>=1.11.0 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from fastf1) (1.16.3)
# Collecting signalrcore (from fastf1)
#   Downloading signalrcore-1.0.2-py3-none-any.whl.metadata (13 kB)
# Collecting timple>=0.1.6 (from fastf1)
#   Downloading timple-0.1.8-py3-none-any.whl.metadata (2.0 kB)
# Collecting websockets>=10.3 (from fastf1)
#   Downloading websockets-17.1-cp313-cp313-win_amd64.whl.metadata (6.5 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: joblib>=1.3.0 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from python-dateutil->fastf1) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.30.0->fastf1) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.30.0->fastf1) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.30.0->fastf1) (2.6.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests>=2.30.0->fastf1) (2025.11.12)
# Requirement already satisfied: attrs>=21.2 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from requests-cache>=1.0.0->fastf1) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache>=1.0.0->fastf1)
#   Downloading cattrs-26.1.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting url-normalize>=2.0 (from requests-cache>=1.0.0->fastf1)
#   Downloading url_normalize-3.0.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting attrs>=21.2 (from requests-cache>=1.0.0->fastf1)
#   Downloading attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cattrs>=22.2->requests-cache>=1.0.0->fastf1) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cryptography->fastf1) (2.0.0)
# Requirement already satisfied: pycparser in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from cffi>=2.0.0->cryptography->fastf1) (2.23)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic->fastf1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic->fastf1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages (from pydantic->fastf1) (0.4.2)
# Collecting msgpack==1.1.2 (from signalrcore->fastf1)
#   Downloading msgpack-1.1.2-cp313-cp313-win_amd64.whl.metadata (8.4 kB)
# Downloading fastf1-3.8.3-py3-none-any.whl (135 kB)
# Downloading requests_cache-1.3.3-py3-none-any.whl (70 kB)
# Downloading cattrs-26.1.0-py3-none-any.whl (73 kB)
# Downloading attrs-26.1.0-py3-none-any.whl (67 kB)
# Downloading timple-0.1.8-py3-none-any.whl (17 kB)
# Downloading url_normalize-3.0.0-py3-none-any.whl (16 kB)
# Downloading websockets-17.1-cp313-cp313-win_amd64.whl (217 kB)
# Downloading cryptography-50.0.1-cp311-abi3-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ---------------------------------------- 3.8/3.8 MB 45.5 MB/s  0:00:00
# Downloading pyjwt-2.13.0-py3-none-any.whl (31 kB)
# Downloading rapidfuzz-3.14.6-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 69.8 MB/s  0:00:00
# Downloading signalrcore-1.0.2-py3-none-any.whl (55 kB)
# Downloading msgpack-1.1.2-cp313-cp313-win_amd64.whl (72 kB)
# Installing collected packages: websockets, url-normalize, rapidfuzz, pyjwt, msgpack, attrs, signalrcore, cryptography, cattrs, timple, requests-cache, fastf1
#
#    ----------------------------------------  0/12 [websockets]
#    ----------------------------------------  0/12 [websockets]
#    ----------------------------------------  0/12 [websockets]
#    ----------------------------------------  0/12 [websockets]
#    --- ------------------------------------  1/12 [url-normalize]
#    --- ------------------------------------  1/12 [url-normalize]
#    ------ ---------------------------------  2/12 [rapidfuzz]
#    ------ ---------------------------------  2/12 [rapidfuzz]
#    ------ ---------------------------------  2/12 [rapidfuzz]
#    ---------- -----------------------------  3/12 [pyjwt]
#    ------------- --------------------------  4/12 [msgpack]
#   Attempting uninstall: attrs
#    ------------- --------------------------  4/12 [msgpack]
#     Found existing installation: attrs 23.2.0
#    ------------- --------------------------  4/12 [msgpack]
#     Uninstalling attrs-23.2.0:
#    ------------- --------------------------  4/12 [msgpack]
#       Successfully uninstalled attrs-23.2.0
#    ------------- --------------------------  4/12 [msgpack]
#    ---------------- -----------------------  5/12 [attrs]
#    -------------------- -------------------  6/12 [signalrcore]
#    -------------------- -------------------  6/12 [signalrcore]
#    -------------------- -------------------  6/12 [signalrcore]
#    -------------------- -------------------  6/12 [signalrcore]
#    ----------------------- ----------------  7/12 [cryptography]
#    ----------------------- ----------------  7/12 [cryptography]
#    ----------------------- ----------------  7/12 [cryptography]
#    ----------------------- ----------------  7/12 [cryptography]
#    ----------------------- ----------------  7/12 [cryptography]
#    ----------------------- ----------------  7/12 [cryptography]
#    -------------------------- -------------  8/12 [cattrs]
#    -------------------------- -------------  8/12 [cattrs]
#    -------------------------- -------------  8/12 [cattrs]
#    ------------------------------ ---------  9/12 [timple]
#    --------------------------------- ------ 10/12 [requests-cache]
#    --------------------------------- ------ 10/12 [requests-cache]
#    ------------------------------------ --- 11/12 [fastf1]
#    ------------------------------------ --- 11/12 [fastf1]
#    ------------------------------------ --- 11/12 [fastf1]
#    ---------------------------------------- 12/12 [fastf1]
#
# Successfully installed attrs-26.1.0 cattrs-26.1.0 cryptography-50.0.1 fastf1-3.8.3 msgpack-1.1.2 pyjwt-2.13.0 rapidfuzz-3.14.6 requests-cache-1.3.3 signalrcore-1.0.2 timple-0.1.8 url-normalize-3.0.0 websockets-17.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fireworks-ai 0.19.20 requires attrs==23.2.0, but you have attrs 26.1.0 which is incompatible.
#
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import fastf1
import pandas as pd
import numpy as np

os.makedirs('cache', exist_ok=True)
fastf1.Cache.enable_cache('cache')

session = fastf1.get_session(2024, 'Bahrain', 'R')
session.load()
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# Cell In[2], line 4
#       1 import fastf1
#       2 import pandas as pd
#       3 import numpy as np
# ----> 4 fastf1.Cache.enable_cache('cache')
#       5
#       6 session = fastf1.get_session(2024, 'Bahrain', 'R')
#       7 session.load()
#
# File c:\Users\aryan\AppData\Local\Programs\Python\Python313\Lib\site-packages\fastf1\req.py:242, in Cache.enable_cache(cls, cache_dir, ignore_version, force_renew, use_requests_cache)
#     239 cache_dir = os.path.expanduser(cache_dir)
#     241 if not os.path.exists(cache_dir):
# --> 242     raise NotADirectoryError("Cache directory does not exist! Please "
#     243                              "check for typos or create it first.")
#     244 cls._CACHE_DIR = cache_dir
#     245 cls._IGNORE_VERSION = ignore_version
#
# NotADirectoryError: Cache directory does not exist! Please check for typos or create it first.
